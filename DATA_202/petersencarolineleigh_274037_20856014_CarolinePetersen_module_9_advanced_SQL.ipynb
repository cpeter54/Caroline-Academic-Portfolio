# %% [markdown]
# # DATA 202 - Module 9: Advanced SQL
# * Instructor: Dr. Josh Fagan

# %% [markdown]
# ### Instructions
#
# Welcome to the Module 9 assignment of DATA 202. This assignment is meant to help you review/familiarize yourself with more advanced commands and concepts in SQL.
#
# To receive credit for a assignment, answer all questions correctly and submit before the deadline listed on Canvas.

# %% [markdown]
# ---
# ### Collaboration Policy
#
# Data science is a collaborative activity. While you may talk with others about the labs, we ask that you **write your solutions individually**. If you do discuss the assignments with others please **include their names** below.

# %% [markdown]
# **Collaborators**: *list collaborators here*
# * X
# * Y

# %% [markdown]
# ## Exercise 0 - Setup

# %% [markdown]
# Run the cell below to import SQLite and load the [SQLite sample database](https://www.sqlitetutorial.net/sqlite-sample-database/)/

# %%
# %load_ext sql
# %sql sqlite:////Users/carolinelpetersen/Desktop/DATA202/data/chinook.db
# Out:
# 'Connected: @/Users/carolinelpetersen/Desktop/DATA202/data/chinook.db'

# %%
# %%sql
# SELECT name FROM sqlite_schema
# WHERE type IN ('table','view')
# AND name NOT LIKE 'sqlite_%'
# ORDER BY 1;
# Out:
#  * sqlite:////Users/carolinelpetersen/Desktop/DATA202/data/chinook.db
# Done.
# [('albums',),
#  ('artists',),
#  ('cats',),
#  ('customers',),
#  ('dogs',),
#  ('employees',),
#  ('genres',),
#  ('invoice_items',),
#  ('invoices',),
#  ('media_types',),
#  ('playlist_track',),
#  ('playlists',),
#  ('tracks',)]

# %% [markdown]
# ## Exercise 1
# Create a table that contains a record for each track that is in a playlist, and the name of the playlist that track is in.
#
# Your table schema should have the columns: `Playlist`, `Track`
#
# **Notes:**
# - Based on the [database diagram](https://www.sqlitetutorial.net/sqlite-sample-database/) you will need to use **two** `INNER JOIN`s.
# This can be done by adding another set of  `INNER JOIN... ON...` lines under the first `FROM... INNER JOIN... ON ...` lines that you create.
# I recommend joining `playlists` with `playlist_track` and then joining `tracks`.
# - Alias the name of the playlist as "Playlist"
# - Alias the name of the track as "Track"
# - Sort the results by playlist name (you can take advantage of your alias here)

# %%
# %%sql
# SELECT p.name AS Playlist, t.name AS Track
# FROM playlists AS p
# INNER JOIN playlist_track AS pt
#     ON p.PlaylistID = pt.PlaylistID
# INNER JOIN tracks AS t
#     ON pt.TrackID = t.TrackID
# ORDER BY Playlist
# Out:
#  * sqlite:////Users/carolinelpetersen/Desktop/DATA202/data/chinook.db
# Done.
# [('90’s Music', 'Fast As a Shark'),
#  ('90’s Music', 'Restless and Wild'),
#  ('90’s Music', 'Princess of the Dawn'),
#  ('90’s Music', 'Walk On Water'),
#  ('90’s Music', 'Love In An Elevator'),
#  ('90’s Music', 'Rag Doll'),
#  ('90’s Music', 'What It Takes'),
#  ('90’s Music', 'Dude (Looks Like A Lady)'),
#  ('90’s Music', "Janie's Got A Gun"),
#  ('90’s Music', "Cryin'"),
#  ('90’s Music', 'Amazing'),
#  ('90’s Music', 'Blind Man'),
#  ('90’s Music', 'Deuces Are Wild'),
#  ('90’s Music', 'The Other Side'),
#  ('90’s Music', 'Crazy'),
#  ('90’s Music', 'Eat The Rich'),
#  ('90’s Music', 'Midnight Cowboy'),
#  ('90’s Music', 'Easy'),
#  ('90’s Music', 'Get Out'),
#  ('90’s Music', 'Ricochet'),
#  ('90’s Music', 'Evidence'),
#  ('90’s Music', 'The Gentle Art Of Making Enemies'),
#  ('90’s Music', 'Star A.D.'),
#  ('90’s Music', 'Cuckoo For Caca'),
#  ('90’s Music', 'Caralho Voador'),
#  ('90’s Music', 'Ugly In The Morning'),
#  ('90’s Music', 'Digging The Grave'),
#  ('90’s Music', 'Take This Bottle'),
#  ('90’s Music', 'King For A Day'),
#  ('90’s Music', 'What A Day'),
#  ('90’s Music', 'The Last To Know'),
#  ('90’s Music', 'Just A Man'),
#  ('90’s Music', 'Absolute Zero'),
#  ('90’s Music', 'Falamansa Song'),
#  ('90’s Music', 'Xote Dos Milagres'),
#  ('90’s Music', 'Rindo À Toa'),
#  ('90’s Music', 'Confidência'),
#  ('90’s Music', 'Asas'),
#  ('90’s Music', 'Doll'),
#  ('90’s Music', 'Monkey Wrench'),
#  ('90’s Music', 'Hey, Johnny Park!'),
#  ('90’s Music', 'My Poor Brain'),
#  ('90’s Music', 'Wind Up'),
#  ('90’s Music', 'Up In Arms'),
#  ('90’s Music', 'My Hero'),
#  ('90’s Music', 'See You'),
#  ('90’s Music', 'Enough Space'),
#  ('90’s Music', 'February Stars'),
#  ('90’s Music', 'Everlong'),
#  ('90’s Music', 'Walking After You'),
#  ('90’s Music', 'New Way Home'),
#  ('90’s Music', 'Entrando Na Sua (Intro)'),
#  ('90’s Music', 'Nervosa'),
#  ('90’s Music', 'Funk De Bamba (Com Fernanda Abreu)'),
#  ('90’s Music', 'Call Me At Cleo´s'),
#  ('90’s Music', 'Olhos Coloridos (Com Sandra De Sá)'),
#  ('90’s Music', 'Zambação'),
#  ('90’s Music', 'Funk Hum'),
#  ('90’s Music', 'Forty Days (Com DJ Hum)'),
#  ('90’s Music', 'Balada Da Paula'),
#  ('90’s Music', 'Dujji'),
#  ('90’s Music', 'Meu Guarda-Chuva'),
#  ('90’s Music', 'Motéis'),
#  ('90’s Music', 'Whistle Stop'),
#  ('90’s Music', '16 Toneladas'),
#  ('90’s Music', 'Divirta-Se (Saindo Da Sua)'),
#  ('90’s Music', 'Forty Days Instrumental'),
#  ('90’s Music', 'Introdução (Live)'),
#  ('90’s Music', 'Palco (Live)'),
#  ('90’s Music', 'Is This Love (Live)'),
#  ('90’s Music', 'Stir It Up (Live)'),
#  ('90’s Music', 'Refavela (Live)'),
#  ('90’s Music', 'Vendedor De Caranguejo (Live)'),
#  ('90’s Music', 'Quanta (Live)'),
#  ('90’s Music', 'Estrela (Live)'),
#  ('90’s Music', 'Pela Internet (Live)'),
#  ('90’s Music', 'Cérebro Eletrônico (Live)'),
#  ('90’s Music', 'Opachorô (Live)'),
#  ('90’s Music', 'Copacabana (Live)'),
#  ('90’s Music', 'A Novidade (Live)'),
#  ('90’s Music', 'Ghandi (Live)'),
#  ('90’s Music', 'De Ouro E Marfim (Live)'),
#  ('90’s Music', 'A Novidade'),
#  ('90’s Music', 'Tenho Sede'),
#  ('90’s Music', 'Theme From The Swan'),
#  ('90’s Music', "Theme From Let's Go Native"),
#  ('90’s Music', 'Corduroy'),
#  ('90’s Music', 'Given To Fly'),
#  ('90’s Music', 'Hail, Hail'),
#  ('90’s Music', 'Daughter'),
#  ('90’s Music', 'Elderly Woman Behind The Counter In A Small Town'),
#  ('90’s Music', 'Untitled'),
#  ('90’s Music', 'MFC'),
#  ('90’s Music', 'Go'),
#  ('90’s Music', 'Red Mosquito'),
#  ('90’s Music', 'Even Flow'),
#  ('90’s Music', 'Off He Goes'),
#  ('90’s Music', 'Nothingman'),
#  ('90’s Music', 'Do The Evolution'),
#  ('90’s Music', 'Better Man'),
#  ('90’s Music', 'Black'),
#  ('90’s Music', "F*Ckin' Up"),
#  ('90’s Music', 'Once'),
#  ('90’s Music', 'Evenflow'),
#  ('90’s Music', 'Alive'),
#  ('90’s Music', 'Why Go'),
#  ('90’s Music', 'Black'),
#  ('90’s Music', 'Jeremy'),
#  ('90’s Music', 'Oceans'),
#  ('90’s Music', 'Porch'),
#  ('90’s Music', 'Garden'),
#  ('90’s Music', 'Deep'),
#  ('90’s Music', 'Release'),
#  ('90’s Music', 'Go'),
#  ('90’s Music', 'Animal'),
#  ('90’s Music', 'Daughter'),
#  ('90’s Music', 'Glorified G'),
#  ('90’s Music', 'Dissident'),
#  ('90’s Music', 'W.M.A.'),
#  ('90’s Music', 'Blood'),
#  ('90’s Music', 'Rearviewmirror'),
#  ('90’s Music', 'Rats'),
#  ('90’s Music', 'Elderly Woman Behind The Counter In A Small Town'),
#  ('90’s Music', 'Leash'),
#  ('90’s Music', 'Indifference'),
#  ('90’s Music', 'ZeroVinteUm'),
#  ('90’s Music', 'Queimando Tudo'),
#  ('90’s Music', 'Hip Hop Rio'),
#  ('90’s Music', 'Bossa'),
#  ('90’s Music', '100% HardCore'),
#  ('90’s Music', 'Biruta'),
#  ('90’s Music', 'Mão Na Cabeça'),
#  ('90’s Music', 'O Bicho Tá Pregando'),
#  ('90’s Music', 'Adoled (Ocean)'),
#  ('90’s Music', 'Seus Amigos'),
#  ('90’s Music', 'Paga Pau'),
#  ('90’s Music', 'Rappers Reais'),
#  ('90’s Music', 'Nega Do Cabelo Duro'),
#  ('90’s Music', 'Hemp Family'),
#  ('90’s Music', 'Quem Me Cobrou?'),
#  ('90’s Music', 'Se Liga'),
#  ('90’s Music', 'Shiny Happy People'),
#  ('90’s Music', 'Me In Honey'),
#  ('90’s Music', 'Radio Song'),
#  ('90’s Music', 'How The West Was Won And Where It Got Us'),
#  ('90’s Music', 'The Wake-Up Bomb'),
#  ('90’s Music', 'New Test Leper'),
#  ('90’s Music', 'Undertow'),
#  ('90’s Music', 'E-Bow The Letter'),
#  ('90’s Music', 'Leave'),
#  ('90’s Music', 'Departure'),
#  ('90’s Music', 'Bittersweet Me'),
#  ('90’s Music', 'Be Mine'),
#  ('90’s Music', 'Binky The Doormat'),
#  ('90’s Music', 'Zither'),
#  ('90’s Music', 'So Fast, So Numb'),
#  ('90’s Music', 'Low Desert'),
#  ('90’s Music', 'Electrolite'),
#  ('90’s Music', 'Losing My Religion'),
#  ('90’s Music', 'Low'),
#  ('90’s Music', 'Near Wild Heaven'),
#  ('90’s Music', 'Endgame'),
#  ('90’s Music', 'Belong'),
#  ('90’s Music', 'Half A World Away'),
#  ('90’s Music', 'Texarkana'),
#  ('90’s Music', 'Country Feedback'),
#  ('90’s Music', 'Infeliz Natal'),
#  ('90’s Music', 'A Sua'),
#  ('90’s Music', 'Papeau Nuky Doe'),
#  ...]

# %% [markdown]
# ### Exercise 1 Grading Notes
#
# Exercise 1 Grade:
#
# 25/25

# %% [markdown]
# ## Exercise 2
# Create a CTE called `playlists_and_tracks` using the query from Exercise 1. You should be able to copy and paste your code from Exercise 1. Keep only the `Name` from `playlists`, aliased as `Playlist`, but adjust your CTE to return all columns from the `tracks` table (you can do this by saying `tracks.*`).
#
# In the main query, group the records by playlist name, show the name of the playlist, the number of tracks per playlist, the number of unique artists per playlist, and the total duration of the playlist.
#
# Your table schema should have the columns: `Playlist`, `NumTrack`, `NumArtist`, `Duration`
#
# **Notes:**
# - Alias the appropriate columns and aggregates to reflect the schema column names.
# - Recall that we use the `DISTINCT` keyword to find unique values in a column.
# - Display the duration as hours

# %%
# %%sql
# WITH playlists_and_tracks AS
# (
#   SELECT p.name AS Playlist, t.*
#     FROM playlists AS p
#     INNER JOIN playlist_track AS pt
#     ON p.PlaylistID = pt.PlaylistID
#     INNER JOIN tracks AS t
#     ON pt.TrackID = t.TrackID
# )
# SELECT Playlist,
#        COUNT(1) AS NumTrack,
#        COUNT(DISTINCT Composer) AS NumArtist,
#        SUM(Milliseconds) / (1000 * 3600) AS Duration
# FROM playlists_and_tracks
# GROUP BY Playlist
# Out:
#  * sqlite:////Users/carolinelpetersen/Desktop/DATA202/data/chinook.db
# Done.
# [('90’s Music', 1477, 439, 110),
#  ('Brazilian Music', 39, 10, 2),
#  ('Classical', 75, 50, 6),
#  ('Classical 101 - Deep Cuts', 25, 19, 1),
#  ('Classical 101 - Next Steps', 25, 20, 2),
#  ('Classical 101 - The Basics', 25, 20, 2),
#  ('Grunge', 15, 8, 1),
#  ('Heavy Metal Classic', 26, 17, 2),
#  ('Music', 6580, 852, 487),
#  ('Music Videos', 1, 0, 0),
#  ('On-The-Go 1', 1, 1, 0),
#  ('TV Shows', 426, 0, 278)]

# %% [markdown]
# ### Exercise 2 Grading Notes
#
# Exercise 2 Grade:
#
# 25/25

# %% [markdown]
# ## Exercise 3
# Lets say we want a table similar to the one above, but only for rock songs.
#
# 1. Copy and Paste your CTE from above
# 2. In the main query join the results with the `genres` table
# 3. Filter out all rows that do not contain the word "Rock" in their genre
# 4. Group the records by genre name and playlist name, show the name of the genre aliased as `Genre`, the name of the playlist, the number of tracks per playlist, the number of unique artists per playlist, and the total duration of the playlist.
#
# **Notes:**
# - You can perform another `INNER JOIN` with genres
# - Remember we have the keyword `LIKE` for determining string contents

# %%
# %%sql
# WITH playlists_and_tracks AS (
#   SELECT p.Name AS Playlist, t.*, g.Name AS Genre
#   FROM playlists AS p
#   INNER JOIN playlist_track AS pt ON p.PlaylistId = pt.PlaylistId
#   INNER JOIN tracks AS t ON pt.TrackId = t.TrackId
#   INNER JOIN genres AS g ON t.GenreId = g.GenreId
#   WHERE g.Name LIKE '%Rock%'
# )
# SELECT Genre,
#        Playlist,
#        COUNT(*) AS NumTrack,
#        COUNT(DISTINCT Composer) AS NumArtist,
#        SUM(Milliseconds) / (1000 * 3600) AS DurationInHours
# FROM playlists_and_tracks
# GROUP BY Genre, Playlist
# Out:
#  * sqlite:////Users/carolinelpetersen/Desktop/DATA202/data/chinook.db
# Done.
# [('Rock', '90’s Music', 621, 169, 50),
#  ('Rock', 'Grunge', 14, 8, 1),
#  ('Rock', 'Heavy Metal Classic', 9, 6, 0),
#  ('Rock', 'Music', 2594, 316, 204),
#  ('Rock And Roll', '90’s Music', 12, 10, 0),
#  ('Rock And Roll', 'Music', 24, 10, 0)]

# %% [markdown]
# ### Exercise 3 Grading Notes
#
#
# Exercise 3 Grade:
#
# 25/25

# %% [markdown]
# ## Exercise 4
# Using what we learned to bridge SQL and Python:
#
# Write a SQL query, on the `tracks` table, to return a table that has each composer, the minimum length of their songs, the maximum length of their songs, and the number of songs they have created. Filter out composers that have one album or less and one song or less in `tracks`.
#
# Run the query to create a `pandas` `DataTable`. Display the first 10 rows of the dataset with the `head()` function.
#
# Query Strategy:
# - You will want to filter out `Composer`s who are NULL
# - You will need to group by the `Composer`
# - You will want to filter your groups to account for number of albums and number of songs

# %%
import pandas as pd

credentials = 'sqlite:////Users/carolinelpetersen/Desktop/DATA202/data/chinook.db'

query = """
SELECT
    Composer,
    MIN(Milliseconds) AS Min_Song_Length,
    MAX(Milliseconds) AS Max_Song_Length,
    COUNT(*) AS Number_of_Songs
FROM
    tracks
WHERE
    Composer IS NOT NULL
GROUP BY
    Composer
HAVING
    COUNT(DISTINCT AlbumId) > 1
    AND COUNT(*) > 1
"""

dataframe = pd.read_sql(query, con = credentials)

dataframe.head(10)
# Out:
#                                          Composer  Min_Song_Length  \
# 0                                    Adrian Smith           269557
# 1                    Adrian Smith/Bruce Dickinson           206367
# 2       Adrian Smith/Bruce Dickinson/Steve Harris           275539
# 3                       Adrian Smith/Steve Harris           232777
# 4  Anthony Kiedis/Chad Smith/Flea/John Frusciante           163787
# 5  Bill Berry-Peter Buck-Mike Mills-Michael Stipe           154148
# 6                                    Billy Corgan           161123
# 7                        Blaze Bayley/Janick Gers           253413
# 8                                 Bruce Dickinson           284238
# 9                    Bruce Dickinson/David Murray           188786
#
#    Max_Song_Length  Number_of_Songs
# 0           344502                5
# 1           386821                6
# 2           391105                8
# 3           508107                5
# 4           496692               19
# 5           437968               25
# 6           473391               31
# 7           330292                2
# 8           408607                3
# 9           254197                3

# %% [markdown]
# ### Exercise 4 Grading Notes
#
# Deductions:
# - Uneeded limit in the sql code (-2)
#
# Exercise 4 Grade:
#
# 23/25

# %% [markdown]
# ---
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. I recommend going to the "Kernel" menu at the top and selecting "Restart & Run All". This will ensure that everything runs correctly when it is run sequentially.

# %% [markdown]
# ---
# ## Final Grade
#
# 98/100
